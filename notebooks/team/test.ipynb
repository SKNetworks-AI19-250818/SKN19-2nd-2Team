# %%
from preprocess import preprocessing_data
from features_01 import feature_age_group, feature_is_single

ROOT_DIR = Path("").resolve().parent.parent
DATA_DIR = ROOT_DIR / "data"
DATA_PATH = DATA_DIR / "analy_data.csv"
SAVE_FILE = DATA_DIR / "prep_data_v1.csv"

df_merge = preprocessing_data(DATA_PATH)
df_merge = feature_age_group(df_merge)
df_merge = feature_is_single(df_merge)
df_merge
# Out:
# (전처리)데이터 크기: (89822, 73) (2개 제외)
#                        exmprs_no   age sex CTPRVN_CODE SPOT_NO       wt_p  \
# 0      2024111170001700102002201  31.0   1          11   00102  380.47075
# 1      2024111170001700102005901  37.0   1          11   00102  380.47075
# 2      2024111170001700102005902  36.0   2          11   00102  376.40383
# 3      2024111170001700102017001  36.0   1          11   00102  380.47075
# 4      2024111170001700191001801  64.0   1          11   00191  119.45059
# ...                          ...   ...  ..         ...     ...        ...
# 89817  2024503970006201711015701  49.0   1          50   01711   51.53645
# 89818  2024503970006201711018701  77.0   1          50   01711   30.93451
# 89819  2024503970006201711021602  64.0   1          50   01711   30.93451
# 89820  2024503970006201711021603  40.0   1          50   01711   51.53645
# 89821  2024503970006201711033101  39.0   1          50   01711   64.94512
#
# ...
