# %%
### 전체 칼럼
"""
 0   조사대상자번호            89822 non-null  object 
 1   만나이                89822 non-null  float64
 2   성별                 89822 non-null  object 
 3   시도번호               89822 non-null  object 
 4   표본지점번호             89822 non-null  object 
 5   개인가중치              89822 non-null  float64
 6   가구원수_전체            89822 non-null  float64
 7   가구원수_만19세이상        89822 non-null  float64
 8   기초생활수급자여부          89801 non-null  float64
 9   월간가구총소득구간          1095 non-null   float64
 10  가구식품안정성여부          89800 non-null  float64
 11  이탈여부               89822 non-null  int64  
 12  아침식사빈도             89822 non-null  float64
 13  영양표시설인지여부          89315 non-null  float64
 14  영양표시영향여부           19738 non-null  float64
 15  체중조절방법_운동          44065 non-null  float64
 16  체중조절방법_단식          44058 non-null  float64
 17  체중조절방법_무처방약물       44058 non-null  float64
 18  구강건강자기평가           89822 non-null  float64
 19  저작불편여부             89822 non-null  float64
 20  점심후양치여부            89812 non-null  float64
 21  점심후양치불가이유          36451 non-null  float64
 22  저녁양치여부             89817 non-null  float64
 23  치과미수진이유            11794 non-null  float64
 24  평생 음주 여부           89822 non-null  object 
 25  연간 음주 빈도           89820 non-null  float64
 26  한 번 섭취 시 음주량       89819 non-null  float64
 27  절주 또는 금주계획 여부      66997 non-null  float64
 28  고강도 신체활동 일수        89822 non-null  float64
 29  중강도 신체활동 일수        89820 non-null  float64
 30  걷기 실천 일수           89818 non-null  float64
 31  최근 1주일 유연성 운동 실천   89821 non-null  float64
 32  스트레스정도             89802 non-null  float64
 33  스트레스상담여부           19337 non-null  float64
 34  취침시간               89587 non-null  float64
 35  기상시간               62246 non-null  float64
 36  화장실각성여부            89818 non-null  float64
 37  악몽경험여부             89807 non-null  float64
 38  기억력저하여부            74573 non-null  float64
 39  상담여부               16733 non-null  float64
 40  치매검사여부             60739 non-null  float64
 41  평생담배제품사용경험         89822 non-null  float64
 42  일반담배평생흡연량          89786 non-null  float64
 43  매일흡연자하루흡연량         89822 non-null  float64
 44  가끔흡연자월간흡연일수        3590 non-null   float64
 45  가끔흡연자일평균흡연량        3595 non-null   float64
 46  과거흡연자흡연기간_년        52018 non-null  float64
 47  과거흡연자흡연기간_월        52013 non-null  float64
 48  과거흡연자하루평균흡연량       52037 non-null  float64
 49  금연유지기간             52054 non-null  float64
 50  궐련형전자담배평생사용        89816 non-null  float64
 51  궐련형매일사용자하루사용량      5920 non-null   float64
 52  궐련형가끔사용자월간일수       2019 non-null   float64
 53  궐련형가끔사용자일평균사용량     2020 non-null   float64
 54  액상형전자담배평생사용        89817 non-null  float64
 55  액상형전자담배현재사용        10432 non-null  float64
 56  최근1년금연시도여부         89822 non-null  float64
 57  금연계획               41947 non-null  float64
 58  가정내흡연자존재           89821 non-null  float64
 59  가정간접흡연노출           2184 non-null   float64
 60  직장간접흡연노출           89821 non-null  float64
 61  교육수준               89788 non-null  float64
 62  졸업상태               88269 non-null  float64
 63  경제활동여부             89818 non-null  float64
 64  직업분류               64814 non-null  float64
 65  종사상지위              64814 non-null  float64
 66  혼인상태               89805 non-null  float64
 67  drb_binge_monthly  7351 non-null   float64
 68  age_group          89822 non-null  float64
 69  is_single          89822 non-null  int64  
 70  fma_14z1_add       88476 non-null  float64
 71  fma_14z1_log       88476 non-null  float64
 72  fma_14z1_group     89571 non-null  float64
 73  fma_dementia_case  89797 non-null  float64
"""
# Out:
# '\n 0   조사대상자번호            89822 non-null  object \n 1   만나이                89822 non-null  float64\n 2   성별                 89822 non-null  object \n 3   시도번호               89822 non-null  object \n 4   표본지점번호             89822 non-null  object \n 5   개인가중치              89822 non-null  float64\n 6   가구원수_전체            89822 non-null  float64\n 7   가구원수_만19세이상        89822 non-null  float64\n 8   기초생활수급자여부          89801 non-null  float64\n 9   월간가구총소득구간          1095 non-null   float64\n 10  가구식품안정성여부          89800 non-null  float64\n 11  이탈여부               89822 non-null  int64  \n 12  아침식사빈도             89822 non-null  float64\n 13  영양표시설인지여부          89315 non-null  float64\n 14  영양표시영향여부           19738 non-null  float64\n 15  체중조절방법_운동          44065 non-null  float64\n 16  체중조절방법_단식          44058 non-null  float64\n 17  체중조절방법_무처방약물       44058 non-null  float64\n 18  구강건강자기평가           89822 non-null  float64\n 19  저작불편여부             89822 non-null  float64\n 20  점심후양치여부   
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import seaborn as sns
from scipy.stats import pointbiserialr

font_path = 'C:/Windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font) #폰트 설정 변경
# plt.rcParams['axes.unicode_minus']=False #마이너스 기호 깨질 때

# %%
# 모델
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, average_precision_score, roc_curve, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### ML 데이터 준비
#
# - data__데이터전처리통합.ipynb 아래 코드에서 담당 카테고리의 변경사항 있을시 수정해서 사용

# %%
# 라이브러리
import os
import json
import pandas as pd
import numpy as np
from pathlib import Path

# 환경설정
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 100)      # 행 전체 표시
pd.set_option('display.max_columns', None)  # 열 전체 표시
pd.set_option('display.width', None)        # 가로폭 자동 맞춤
pd.set_option('display.max_colwidth', None) # 셀 안의 텍스트 생략 방지
pd.set_option('display.float_format', '{:.6f}'.format)

# 경로 설정
ROOT_DIR = Path("").resolve().parent.parent

# 데이터 경로
DATA_DIR = ROOT_DIR / "data"
DATA_PATH = DATA_DIR / "analy_data.csv"
SAVE_FILE = "preprocessed_v1.csv"

# JSON 컬럼 관리 파일 로드
with open("../team/columns.json", "r", encoding="utf-8") as f:
    columns_dict = json.load(f)

# 공통 함수 
def get_columns(*categories):
    """columns.json의 카테고리별 use=y 컬럼 추출"""
    selected = []
    for cat in categories:
        for col, meta in columns_dict[cat].items():
            if meta.get("use", "n") == "y": 
                selected.append(col)
    
    if "churn" not in selected:
        selected.append("churn")

    if "exmprs_no" not in selected:
        selected.append("exmprs_no")

    return selected

def rename_to_kor(df):
    """columns.json의 name으로 한글 컬럼명 매핑"""
    rename_map = {
        col: meta["name"]
        for cat in columns_dict.values()
        for col, meta in cat.items()
        if col in df.columns
    }
    return df.rename(columns=rename_map)

# 1. 기본정보 + 가구조사 
def preprocess_basic_house(data_path):
    cols = get_columns("기본정보", "가구조사")
    df = pd.read_csv(data_path, usecols=cols)

    # 'b' 문자 전처리
    if "exmprs_no" in df.columns:
        df['exmprs_no'] = df['exmprs_no'].apply(lambda x: x.split("'")[1])

    if "CTPRVN_CODE" in df.columns:
        df['CTPRVN_CODE'] = df['CTPRVN_CODE'].apply(lambda x: x.split("'")[1])
    
    if "SPOT_NO" in df.columns:
        df['SPOT_NO'] = df['SPOT_NO'].apply(lambda x: x.split("'")[1])
    
    if "sex" in df.columns:
        df['sex'] = df['sex'].apply(lambda x: 1 if x == 1 else 2).astype(str)

    # NaN 변경
    for col in ["fma_04z1", "nue_01z1", "fma_27z1", "fma_26z1"]:
        if col in df.columns:
            df.loc[df[col] >= 7, col] = np.nan

    for col in ["fma_13z1", "fma_14z1"]:
        if col in df.columns:
            df.loc[df[col] >= 77777, col] = np.nan

    for col in ["fma_24z2"]:
            if col in df.columns:
                df.loc[df[col] >= 77, col] = np.nan

    return df

# 2. 식생활 + 비만및체중조절 + 구강건강
def preprocess_diet_obesity_oral(data_path):
    cols = get_columns("식생활", "비만및체중조절", "구강건강")
    df = pd.read_csv(data_path, usecols=cols)

    # 'b' 문자 전처리
    if "exmprs_no" in df.columns:
        df['exmprs_no'] = df['exmprs_no'].apply(lambda x: x.split("'")[1])

    # NaN 변경
    for col in ["nua_01z2", "nuc_02z1", "nuc_03z1", "obb_02a1", "obb_02b1", "obb_02d1", "ora_01z1", "orb_01z1", "ord_01d2", "ord_05z1", "ord_01f3"]:
        if col in df.columns:
            df.loc[df[col] >= 7, col] = np.nan

    for col in ["ore_03z2"]:
            if col in df.columns:
                df.loc[df[col] >= 77, col] = np.nan

    return df

# 3. 음주 + 신체활동
def preprocess_drink_physical(data_path):
    cols = get_columns("음주", "신체활동")
    df = pd.read_csv(data_path, usecols=cols)

    # 'b' 문자 전처리
    if "exmprs_no" in df.columns:
        df['exmprs_no'] = df['exmprs_no'].apply(lambda x: x.split("'")[1])

    # 값 변경
    if "drb_01z3" in df.columns:
        df["drb_01z3"] = df["drb_01z3"].replace(8, 1)

    if "drb_03z1" in df.columns:
        df["drb_03z1"] = df["drb_03z1"].replace(8, -1)

    # NaN 변경 
    for col in ["drb_01z3", "drb_03z1", "drg_01z3", "pha_11z1", "drb_04z1", "drb_05z1"]:
        if col in df.columns:
            df.loc[df[col] >= 7, col] = np.nan

    for col in ["pha_04z1", "pha_07z1", "phb_01z1"]:
            if col in df.columns:
                df.loc[df[col] >= 77, col] = np.nan

    return df

# 4. 정신건강 + 보건이용
def preprocess_mental_health(data_path):
    cols = get_columns("정신건강", "보건이용")
    df = pd.read_csv(data_path, usecols=cols)

    # 'b' 문자 전처리
    if "exmprs_no" in df.columns:
        df['exmprs_no'] = df['exmprs_no'].apply(lambda x: x.split("'")[1])

    # NaN 변경 
    for col in ["mta_01z1", "mta_02z1", "mtc_12c1", "mtc_12h1", "mtj_05z2", "mtj_10z1", "mtj_11z1"]:
        if col in df.columns:
            df.loc[df[col] >= 7, col] = np.nan

    for col in ["edit_mtc_03z1",  "mtc_08z1"]:
            if col in df.columns:
                df.loc[df[col] >= 77, col] = np.nan

    return df

# 5. 건강행태 + 교육및경제활동
def preprocess_behavior_education(data_path):
    cols = get_columns("건강행태", "교육및경제활동")
    df = pd.read_csv(data_path, usecols=cols)

    # 'b' 문자 전처리
    if "exmprs_no" in df.columns:
        df['exmprs_no'] = df['exmprs_no'].apply(lambda x: x.split("'")[1])

    # NaN 변경
    for col in ["smf_01z1", "sma_01z1", "sma_03z2", "smb_09z1", "sma_36z1", "sma_37z1", "sma_08z1", "sma_12z2"\
                "smd_02z3", "smd_01z3", "smc_08z2", "smc_09z2", "smc_10z2", "sob_02z1", "soa_01z1", "soa_07z1", "sod_02z3"]:
        if col in df.columns:
            df.loc[df[col] >= 7, col] = np.nan

    for col in ["smb_02z1", "smb_05z1", "sma_11z2", "sob_01z1", "soa_06z2", "smb_12z1"]:
            if col in df.columns:
                df.loc[df[col] >= 77, col] = np.nan

    for col in ["smb_13z1", "smb_03z1", "smb_04z1", "smb_06z1", "smb_11z1"]:
            if col in df.columns:
                df.loc[df[col] >= 777, col] = np.nan
    return df

df_basic = preprocess_basic_house(DATA_PATH)
df_health = preprocess_diet_obesity_oral(DATA_PATH)
df_drink = preprocess_drink_physical(DATA_PATH)
df_mental = preprocess_mental_health(DATA_PATH)
df_behavior = preprocess_behavior_education(DATA_PATH)

dfs = [df_basic, df_health, df_drink, df_mental, df_behavior]
df_merge = dfs[0]
for temp in dfs[1:]:
    join_cols = [c for c in ["exmprs_no", "churn"] if c in df_merge.columns and c in temp.columns]
    if join_cols:
        df_merge = pd.merge(df_merge, temp, on=join_cols, how="outer")

print("컬럼 식별 완료된 데이터 크기:", df_merge.shape,'-2')
print(f"결측치 비율: (평균) {df_merge.isna().mean().mean() * 100:.2f}%")

#=========================
# 추가 전처리
#=========================
# doyeon
#=========================
# '월간 폭음 경험(남)', '월간 폭음 경험(여)' ['drb_04z1', 'drb_05z1'] -> '월간 폭음 경험' ['drb_binge_monthly'] 통합
df_merge['sex'] = df_merge['sex']
df_merge['drb_binge_monthly'] = np.where(df_merge['sex'] == 1, df_merge['drb_04z1'], df_merge['drb_05z1'])
df_merge.drop(['drb_04z1', 'drb_05z1'], axis=1, inplace=True)

# 값변경
df_merge['drb_binge_monthly'] = df_merge['drb_binge_monthly'].replace(8, -1)
df_merge.loc[df_merge['drb_binge_monthly'] >= 7, 'drb_binge_monthly'] = np.nan

# 범주형 칼럼 object형 변환
df_merge['dra_01z1'] = df_merge['dra_01z1'].astype('object')

#=========================
# soso
#=========================
# 연령대
df_merge['age_group'] = (df_merge['age'] // 10) * 10

# 1인가구
df_merge['is_single'] = np.where((df_merge['mbhld_co'] <= 1), 1, 0)

# 월간소득 기준 가구소득컬럼 통합
df_merge['fma_14z1_add'] = df_merge['fma_14z1'] 
df_merge['fma_14z1_add'] = round(df_merge['fma_14z1_add'].fillna(df_merge['fma_13z1'] / 12))
df_merge['fma_14z1_log'] = np.log1p(df_merge['fma_14z1_add'])

bins = [0, 50, 100, 200, 300, 400, 500, 600, float('inf')]
labels = [1, 2, 3, 4, 5, 6, 7, 8]
df_merge['fma_14z1_group'] = pd.cut(df_merge['fma_14z1_add'], bins=bins, labels=labels, right=False)
df_merge['fma_14z1_group'] = np.where(df_merge['fma_14z1_group'].isna(), df_merge['fma_24z2'].astype(float), df_merge['fma_14z1_group'])

# 치매가족여부
def get_dementia_case(row):
    if row['fma_27z1'] == 1 and row['fma_26z1'] == 1:
        return 1 # 치매가족 있음 + 같이 거주
    elif row['fma_27z1'] == 1 and row['fma_26z1'] == 2:
        return 2 # 치매가족 있음 + 비거주
    elif row['fma_27z1'] == 2:
        return 3 # 치매가족 없음
    else:
        return np.nan

df_merge['fma_dementia_case'] = df_merge.apply(get_dementia_case, axis=1)
df_merge.drop(['fma_13z1', 'fma_14z1','fma_27z1','fma_26z1'], axis=1, inplace=True)
print("추가 전처리 후 데이터 크기:", df_merge.shape ,'-2')
print("exmprs_no, wt_p 필요시 활용하기 위해 포함해놓음, 제외하고 사용")
# Out:
# 컬럼 식별 완료된 데이터 크기: (89822, 73) -2
# 결측치 비율: (평균) 27.03%
# 추가 전처리 후 데이터 크기: (89822, 74) -2
# exmprs_no, wt_p 필요시 활용하기 위해 포함해놓음, 제외하고 사용

# %%
# drb_binge_monthly의 결측치를 1 전혀 없다로 통일
# df_merge['drb_binge_monthly'].fillna(1, inplace=True)

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89822 entries, 0 to 89821
# Data columns (total 74 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   exmprs_no          89822 non-null  object
#  1   age                89822 non-null  float64
#  2   sex                89822 non-null  object
#  3   CTPRVN_CODE        89822 non-null  object
#  4   SPOT_NO            89822 non-null  object
#  5   wt_p               89822 non-null  float64
#  6   mbhld_co           89822 non-null  float64
#  7   reside_adult_co    89822 non-null  float64
#  8   fma_04z1           89801 non-null  float64
#  9   fma_24z2           1095 non-null   float64
#  10  nue_01z1           89800 non-null  float64
#  11  churn              89822 non-null  int64
#  12  nua_01z2           89822 non-null  float64
#  13  nuc_02z1           89315 non-null  float64
#  14  nuc_03z1           19738 non-null  float64
# ...

# %%
# 한글컬럼으로 확인할 시 사용
df_merge_kor = rename_to_kor(df_merge)

# %% [markdown]
# ---

# %% [markdown]
# ### 모델에 들어가는 피처 핸들링하고 테스트 해보기 (포맷 고정)

# %% [markdown]
# ##### float형 -> object형 변환

# %%
# float -> object 피쳐 변환
object_col = [
 8,#  기초생활수급자여부          89801 non-null  float64
 10,#  가구식품안정성여부          89800 non-null  float64
 15,#  체중조절방법_운동          44065 non-null  float64
 16,#  체중조절방법_단식          44058 non-null  float64
 17,#  체중조절방법_무처방약물       44058 non-null  float64

 18,#  구강건강자기평가           89822 non-null  float64
 19,#  저작불편여부             89822 non-null  float64
 20,#  점심후양치여부            89812 non-null  float64
 21,#  점심후양치불가이유          36451 non-null  float64
 22,#  저녁양치여부             89817 non-null  float64
 23,#  치과미수진이유            11794 non-null  float64
 33,# 스트레스상담여부           19337 non-null  float64

 36,#  화장실각성여부            89818 non-null  float64
 37,#  악몽경험여부             89807 non-null  float64
 38,#  기억력저하여부            74573 non-null  float64
 39,#  상담여부               16733 non-null  float64
 40,#  치매검사여부             60739 non-null  float64

 41,#  평생담배제품사용경험         89822 non-null  float64
 50,#  궐련형전자담배평생사용        89816 non-null  float64
 56,#  최근1년금연시도여부         89822 non-null  float64
 57,#  금연계획               41947 non-null  float64
 58,#  가정내흡연자존재           89821 non-null  float64

 59,#  가정간접흡연노출           2184 non-null   float64
 60,#  직장간접흡연노출           89821 non-null  float64
 63,#  경제활동여부             89818 non-null  float64
 64,#  직업분류               64814 non-null  float64
 65,#  종사상지위              64814 non-null  float64
 66,#  혼인상태               89805 non-null  float64
 68,#  age_group          89822 non-null  float64
 69,#  is_single          89822 non-null  int64
 72,# fma_14z1_group     89571 non-null  float64
 73 #  fma_dementia_case  89797 non-null  float64 치매 가족 여부
]

# 인덱스 번호로부터 컬럼 이름 추출
cols_to_object = df_merge.columns[object_col]

# 각 컬럼을 object 타입으로 변환
df_merge[cols_to_object] = df_merge[cols_to_object].astype('object')

df_merge_kor = rename_to_kor(df_merge)

print(df_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89822 entries, 0 to 89821
# Data columns (total 74 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   exmprs_no          89822 non-null  object
#  1   age                89822 non-null  float64
#  2   sex                89822 non-null  object
#  3   CTPRVN_CODE        89822 non-null  object
#  4   SPOT_NO            89822 non-null  object
#  5   wt_p               89822 non-null  float64
#  6   mbhld_co           89822 non-null  float64
#  7   reside_adult_co    89822 non-null  float64
#  8   fma_04z1           89801 non-null  object
#  9   fma_24z2           1095 non-null   float64
#  10  nue_01z1           89800 non-null  object
#  11  churn              89822 non-null  int64
#  12  nua_01z2           89822 non-null  float64
#  13  nuc_02z1           89315 non-null  float64
#  14  nuc_03z1           19738 non-null  float64
# ...

# %% [markdown]
# ##### 모델 테스트 1: 로지스틱 회귀

# %%
# 결측치 처리

# %%
# 파생 변수 생성

# %%
# 인코딩

# %%
# 최종 피처 선택
columns_1 = [
    #0   조사대상자번호            89822 non-null  object
    #1   만나이                89822 non-null  float64

    2,  #   성별                 89822 non-null  object
    3,  #   시도번호               89822 non-null  object

    #4   표본지점번호             89822 non-null  object
    #5   개인가중치              89822 non-null  float64

    #6   가구원수_전체            89822 non-null  float64
    7,  #   가구원수_만19세이상        89822 non-null  float64
    8,  #   기초생활수급자여부          89801 non-null  object
    
    #9   월간가구총소득구간          1095 non-null   float64
    
    10, #  가구식품안정성여부          89800 non-null  object
    11, #  이탈여부               89822 non-null  int64  ------------------------------------> churn
    12, #  아침식사빈도             89822 non-null  float64
    
    #13  영양표시설인지여부          89315 non-null  float64
    #14  영양표시영향여부           19738 non-null  float64
    
    #15  체중조절방법_운동          44065 non-null  object
    #16  체중조절방법_단식          44058 non-null  object
    #17  체중조절방법_무처방약물       44058 non-null  object
    
    18, #  구강건강자기평가           89822 non-null  object
    19, #  저작불편여부             89822 non-null  object
    20, #  점심후양치여부            89812 non-null  object
    
    #21  점심후양치불가이유          36451 non-null  object
    
    22, #  저녁양치여부             89817 non-null  object
    
    #23  치과미수진이유            11794 non-null  object

    24, #  평생 음주 여부           89822 non-null  object
    25, #  연간 음주 빈도           89820 non-null  float64
    26, #  한 번 섭취 시 음주량       89819 non-null  float64
    27, #  절주 또는 금주계획 여부      66997 non-null  float64
    28, #  고강도 신체활동 일수        89822 non-null  float64
    29, #  중강도 신체활동 일수        89820 non-null  float64
    30, # 걷기 실천 일수           89818 non-null  float64
    31, #  최근 1주일 유연성 운동 실천   89821 non-null  float64
    32, #  스트레스정도             89802 non-null  float64
    
    #33  스트레스상담여부           19337 non-null  object
    
    34, #  취침시간               89587 non-null  float64
    # 35  기상시간               62246 non-null  float64
    36, #  화장실각성여부            89818 non-null  object
    
    #37  악몽경험여부             89807 non-null  object
    
    38, #  기억력저하여부            74573 non-null  object
    
    #39  상담여부               16733 non-null  object
    
    #40  치매검사여부             60739 non-null  object
    
    #41  평생담배제품사용경험         89822 non-null  object -> 흡연자 or 금연자 대상이므로 모두 사용 경험이 있음. --
    
    #42  일반담배평생흡연량          89786 non-null  float64
    #43  매일흡연자하루흡연량         89822 non-null  float64 -> 값 처리 필요?
    
    #44  가끔흡연자월간흡연일수        3590 non-null   float64 --
    #45  가끔흡연자일평균흡연량        3595 non-null   float64
    
    #46  과거흡연자흡연기간_년        52018 non-null  float64 -> churn 1일 때 row만 유의미한 응답 --
    
    #47  과거흡연자흡연기간_월        52013 non-null  float64 --
    #48  과거흡연자하루평균흡연량       52037 non-null  float64
    #49  금연유지기간             52054 non-null  float64 --
    #50  궐련형전자담배평생사용        89816 non-null  object
    #51  궐련형매일사용자하루사용량      5920 non-null   float64 --
    #52  궐련형가끔사용자월간일수       2019 non-null   float64 --
    #53  궐련형가끔사용자일평균사용량     2020 non-null   float64 --
    #54  액상형전자담배평생사용        89817 non-null  float64 --
    #55  액상형전자담배현재사용        10432 non-null  float64 --
    
    #56  최근1년금연시도여부         89822 non-null  object --
    
    #57  금연계획               41947 non-null  object    --
    #58  가정내흡연자존재           89821 non-null  object
    #59  가정간접흡연노출           2184 non-null   object
    #60, 직장간접흡연노출           89821 non-null  object
    
    61, #  교육수준               89788 non-null  float64
    62, #  졸업상태               88269 non-null  float64
    63, #  경제활동여부             89818 non-null  object
    64, #  직업분류               64814 non-null  object
    65, #  종사상지위              64814 non-null  object
    66, #  혼인상태               89805 non-null  object
    #67,  drb_binge_monthly  7351 non-null   float64
    68, #  age_group          89822 non-null  object
    
    #69  is_single          89822 non-null  object
    #70  fma_14z1_add       88476 non-null  float64
    #71  fma_14z1_log       88476 non-null  float64
    
    72, #  fma_14z1_group     89571 non-null  float64
    73 #  fma_dementia_case  89797 non-null  float64
]
len(columns_1)
# Out:
# 32

# %%
# 결측치 drop (NaN 처리 못하는 로지스틱 회귀 모델 때문에 값 대체 또는 drop이 필요하나, 다른 카테고리에 대한 피쳐 이해 시간을 확보할 수 없어 drop 처리)
df_test1 = df_merge_kor.iloc[:, columns_1]
df_test1.dropna(inplace=True)
print(df_test1.shape)
# Out:
# (40418, 32)

# %%
df_test1.groupby('이탈여부')['이탈여부'].count()
# 편향 확인
# Out:
# 이탈여부
# 0    19548
# 1    20870
# Name: 이탈여부, dtype: int64

# %%
# 모델
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, average_precision_score, roc_curve, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 분리
X = df_test1.drop('이탈여부', axis=1)
y = df_test1['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
model = LogisticRegression(random_state=2)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance = pd.Series(model.coef_[0], index=X.columns)
print(feature_importance.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (32334, 31) (32334,) (8084, 31) (8084,)
#
# Accuracy: 0.6551212271152894
# 성별                   0.283196
# 스트레스정도               0.154503
# 화장실각성여부              0.137620
# 절주 또는 금주계획 여부        0.094402
# 기초생활수급자여부            0.070796
# 최근 1주일 유연성 운동 실천     0.062572
# 교육수준                 0.050043
# age_group            0.038508
# fma_14z1_group       0.025812
# 고강도 신체활동 일수          0.018569
# 저작불편여부               0.015375
# 걷기 실천 일수             0.008337
# 취침시간                 0.005458
# 중강도 신체활동 일수         -0.001486
# 시도번호                -0.001963
# 종사상지위               -0.031600
# 가구식품안정성여부           -0.034429
# 직업분류                -0.041458
# 가구원수_만19세이상         -0.043435
# 졸업상태                -0.061466
# fma_dementia_case   -0.095057
# 평생 음주 여부            -0.098943
# 경제활동여부              -0.098943
# 연간 음주 빈도            -0.114538
# 한 번 섭취 시 음주량        -0.134691
# 아침식사빈도              -0.165302
# 구강건강자기평가            -0.174116
# 저녁양치여부              -0.179403
# ...

# %%
# 비선형적 피처-타겟 관계를 잘 학습하지 못함
# 범주형 따로 피쳐 스케일링 필요(원핫 인코딩 등)
# 앙상블이 아무래도 좋은 성능을 냄 -> CatBoost 전환

# %% [markdown]
# ##### 모델 테스트2

# %% [markdown]
# test2
# - 임의로 고른 피쳐로 테스트
# 0.6889
# 피쳐 수 35
#
#
# test3
# - test2에서 피쳐 중요도 낮은 칼럼 제거, '수면시간' 생성
# 0.6912
# 피쳐 수 31
#
#
#
# -- 수면시간 결측치가 2만7천 건임을 나중에 확인, '기상시간' 처리 코드 수정 후 (기존 7 이상이면 NaN. 그러나 77 이상일 때 NaN처리가 옳음) 다시 test4부터 진행
#
#
# test4
# - '수면시간' 더한, 흡연 카테고리 제외 모든 피쳐로 학습
# 0.6960
# 피쳐 수 42
#
#
# -- drb_binge_monthly의 결측치를 1 전혀 없다로 모두 수정.
#
# test5
# - test4에서 피쳐 중요도가 1 이상 나온 것 + 결측치만 학습
# 0.6951
# 피쳐 수 27
#
# test6
# - (1) test5에서 피쳐 중요도가 낮게 나온 'drb_binge_monthly' 제거.
# - (2) 체중조절방법 - 운동, 단식, 무처방약물 -> 체중조절방법 파생 변수 생성
# - (3) '평생 음주 여부'의 정보가 '연간 음주 빈도'에 포함되므로 제거.
#
# 0.6916
# 피쳐 수 23
#
#
# test7
# - (1) 고강도, 중강도, 걷기로 '활동점수_가중치' 파생 변수 생성
#
# 0.6916
# 피쳐 수 24
#
# + (2) 평생 음주 여부 다시 추가
#
# 0.6947
# 피쳐 수 25
#
#
# test7-1
# - 동일 피쳐로 진행, 모든 하이퍼파라미터값 부여 x
# - 자동 지정된 학습률 - 0.064, iteration-1000
#
# 0.6942
# 피쳐 수 25

# %%
# CatBoost 사용
# !pip install catboost

# %%
# 피쳐 선택
# 최종 피처 선택
columns_2 = [
    #0   조사대상자번호            89822 non-null  object
    #1   만나이                89822 non-null  float64

    2,  #   성별                 89822 non-null  object
    3,  #   시도번호               89822 non-null  object

    #4   표본지점번호             89822 non-null  object
    #5   개인가중치              89822 non-null  float64

    #6   가구원수_전체            89822 non-null  float64
    7,  #   가구원수_만19세이상        89822 non-null  float64
    8,  #   기초생활수급자여부          89801 non-null  object
    
    #9   월간가구총소득구간          1095 non-null   float64
    
    10, #  가구식품안정성여부          89800 non-null  object
    11, #  이탈여부               89822 non-null  int64  ------------------------------------> churn
    12, #  아침식사빈도             89822 non-null  float64
    
    13, #  영양표시설인지여부          89315 non-null  float64
    #14  영양표시영향여부           19738 non-null  float64
    
    #15  체중조절방법_운동          44065 non-null  object
    #16  체중조절방법_단식          44058 non-null  object
    #17  체중조절방법_무처방약물       44058 non-null  object
    
    18, #  구강건강자기평가           89822 non-null  object
    19, #  저작불편여부             89822 non-null  object
    20, #  점심후양치여부            89812 non-null  object
    
    #21  점심후양치불가이유          36451 non-null  object
    
    22, #  저녁양치여부             89817 non-null  object
    
    #23  치과미수진이유            11794 non-null  object

    24, #  평생 음주 여부           89822 non-null  object
    25, #  연간 음주 빈도           89820 non-null  float64
    26, #  한 번 섭취 시 음주량       89819 non-null  float64
    27, #  절주 또는 금주계획 여부      66997 non-null  float64
    28, #  고강도 신체활동 일수        89822 non-null  float64
    29, #  중강도 신체활동 일수        89820 non-null  float64
    30, # 걷기 실천 일수           89818 non-null  float64
    31, #  최근 1주일 유연성 운동 실천   89821 non-null  float64
    32, #  스트레스정도             89802 non-null  float64
    
    #33  스트레스상담여부           19337 non-null  object
    
    34, #  취침시간               89587 non-null  float64
    # 35  기상시간               62246 non-null  float64
    36, #  화장실각성여부            89818 non-null  object
    
    #37  악몽경험여부             89807 non-null  object
    
    38, #  기억력저하여부            74573 non-null  object
    
    #39  상담여부               16733 non-null  object
    
    40, #  치매검사여부             60739 non-null  object
    
    #41  평생담배제품사용경험         89822 non-null  object -> 흡연자 or 금연자 대상이므로 모두 사용 경험이 있음. --
    
    #42  일반담배평생흡연량          89786 non-null  float64
    #43  매일흡연자하루흡연량         89822 non-null  float64 -> 값 처리 필요?
    
    #44  가끔흡연자월간흡연일수        3590 non-null   float64 --
    #45  가끔흡연자일평균흡연량        3595 non-null   float64
    
    #46  과거흡연자흡연기간_년        52018 non-null  float64 -> churn 1일 때 row만 유의미한 응답 --
    
    #47  과거흡연자흡연기간_월        52013 non-null  float64 --
    #48  과거흡연자하루평균흡연량       52037 non-null  float64
    #49  금연유지기간             52054 non-null  float64 --
    #50  궐련형전자담배평생사용        89816 non-null  object
    #51  궐련형매일사용자하루사용량      5920 non-null   float64 --
    #52  궐련형가끔사용자월간일수       2019 non-null   float64 --
    #53  궐련형가끔사용자일평균사용량     2020 non-null   float64 --
    #54  액상형전자담배평생사용        89817 non-null  float64 --
    #55  액상형전자담배현재사용        10432 non-null  float64 --
    
    #56  최근1년금연시도여부         89822 non-null  object --
    
    #57  금연계획               41947 non-null  object    --
    #58  가정내흡연자존재           89821 non-null  object
    #59  가정간접흡연노출           2184 non-null   object
    #60, 직장간접흡연노출           89821 non-null  object
    
    61, #  교육수준               89788 non-null  float64
    62, #  졸업상태               88269 non-null  float64
    63, #  경제활동여부             89818 non-null  object
    64, #  직업분류               64814 non-null  object
    65, #  종사상지위              64814 non-null  object
    66, #  혼인상태               89805 non-null  object
    67, #  drb_binge_monthly  7351 non-null   float64
    68, #  age_group          89822 non-null  object
    
    69, #  is_single          89822 non-null  object
    #70  fma_14z1_add       88476 non-null  float64
    71, #   fma_14z1_log       88476 non-null  float64
    
    #72, fma_14z1_group     89571 non-null  float64
    73 #  fma_dementia_case  89797 non-null  float64 치매 가족 여부
]
print(len(columns_2))
# Out:
# 36

# %%
# 모델이 학습할 데이터프레임 생성
df_test2 = df_merge_kor.iloc[:, columns_2]

# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test2.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test2.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test2[col] = df_test2[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

# %%
# 모델

# 데이터 분리
X = df_test2.drop('이탈여부', axis=1)
y = df_test2['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    verbose=100
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 35) (71857,) (17965, 35) (17965,)
#
# 0:	learn: 0.6515301	total: 178ms	remaining: 1m 28s
# 100:	learn: 0.6929596	total: 13.9s	remaining: 54.8s
# 200:	learn: 0.6986097	total: 27s	remaining: 40.2s
# 300:	learn: 0.7032579	total: 40.3s	remaining: 26.7s
# 400:	learn: 0.7062499	total: 53.9s	remaining: 13.3s
# 499:	learn: 0.7089080	total: 1m 7s	remaining: 0us
# Accuracy: 0.6889507375452268
# age_group           15.652735
# 혼인상태                 8.490960
# 한 번 섭취 시 음주량         8.020208
# 아침식사빈도               5.532906
# 교육수준                 5.342892
# 화장실각성여부              4.131461
# 연간 음주 빈도             3.870387
# 취침시간                 3.626117
# 성별                   3.355687
# 평생 음주 여부             3.237050
# 최근 1주일 유연성 운동 실천     3.223252
# 치매검사여부               3.183502
# 직업분류                 2.694913
# 구강건강자기평가             2.693919
# fma_14z1_log         2.595725
# 절주 또는 금주계획 여부        2.486091
# 스트레스정도               2.308906
# 점심후양치여부              2.131647
# ...

# %%
# 중요도 내림차순 정렬
feature_importance = feature_importance.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance.T.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# df_merge_kor['기상시간'].isna().sum()
# Out:
# np.int64(27576)

# %% [markdown]
# ##### '수면시간' 피쳐 생성

# %%
# 수면시간 피쳐 생성
df_merge_kor['수면시간'] = (df_merge_kor['기상시간'] - df_merge_kor['취침시간']).apply(lambda x: x if x >= 0 else x + 24)

# 수면시간이 3시간 미만이거나 13시간 초과하는 row 개수 조회
print(df_merge_kor.loc[(df_merge_kor['수면시간'] < 3) | (df_merge_kor['수면시간'] > 13), '수면시간'].count()) # 166
# '기상시간', '취침시간' 결측치로 인한 기존 NaN 개수 조회
print(df_merge_kor['수면시간'].isna().sum()) # 241

# 166건 -> NaN 처리
df_merge_kor.loc[(df_merge_kor['수면시간'] < 3) | (df_merge_kor['수면시간'] > 13), '수면시간'] = np.nan
print(df_merge_kor['수면시간'].isna().sum()) # 407
# Out:
# 166
# 241
# 407

# %% [markdown]
# ##### 모델 테스트 3

# %%
# 피쳐 선택
# 1-1. 중요도가 낮게 나온 '가구원수_만19세이상', 'is_single' 제거 -> 가구원수_전체 칼럼과도 연결되어 있음
# 1-2. 마찬가지로 낮은 '영양표시설인지여부' 제거
# 2. 치매가족여부 fma_dementia_case도 없음(3)이 89천건 중 79천건, 중요도 낮으므로 제거
# 3. 취침시간, 기상시간으로 '수면시간' 새 피쳐 생성

# 최종 피처 선택
columns_3 = [
    #0   조사대상자번호            89822 non-null  object
    #1   만나이                89822 non-null  float64

    2,  #   성별                 89822 non-null  object
    3,  #   시도번호               89822 non-null  object

    #4   표본지점번호             89822 non-null  object
    #5   개인가중치              89822 non-null  float64

    6,  #   가구원수_전체            89822 non-null  float64

    #7,   가구원수_만19세이상        89822 non-null  float64

    8,  #   기초생활수급자여부          89801 non-null  object
    
    #9   월간가구총소득구간          1095 non-null   float64
    
    10, #  가구식품안정성여부          89800 non-null  object
    11, #  이탈여부               89822 non-null  int64  ------------------------------------> churn
    12, #  아침식사빈도             89822 non-null  float64
    
    #13  영양표시설인지여부          89315 non-null  float64
    #14  영양표시영향여부           19738 non-null  float64
    
    #15  체중조절방법_운동          44065 non-null  object
    #16  체중조절방법_단식          44058 non-null  object          -> 이거 어떻ㄱ게 하고 싶은데. . .
    #17  체중조절방법_무처방약물       44058 non-null  object
    
    18, #  구강건강자기평가           89822 non-null  object
    19, #  저작불편여부             89822 non-null  object
    20, #  점심후양치여부            89812 non-null  object
    
    #21  점심후양치불가이유          36451 non-null  object
    
    22, #  저녁양치여부             89817 non-null  object  -> 이것도 어떻게 하고 싶은데...
    
    #23  치과미수진이유            11794 non-null  object

    24, #  평생 음주 여부           89822 non-null  object
    25, #  연간 음주 빈도           89820 non-null  float64
    26, #  한 번 섭취 시 음주량       89819 non-null  float64
    27, #  절주 또는 금주계획 여부      66997 non-null  float64
    28, #  고강도 신체활동 일수        89822 non-null  float64
    29, #  중강도 신체활동 일수        89820 non-null  float64
    30, # 걷기 실천 일수           89818 non-null  float64
    31, #  최근 1주일 유연성 운동 실천   89821 non-null  float64
    
    32, #  스트레스정도             89802 non-null  float64
    
    #33  스트레스상담여부           19337 non-null  object
    
    #34  취침시간               89587 non-null  float64
    #35  기상시간               62246 non-null  float64
    
    36, #  화장실각성여부            89818 non-null  object
    
    #37  악몽경험여부             89807 non-null  object
    
    38, #  기억력저하여부            74573 non-null  object
    
    #39  상담여부               16733 non-null  object
    
    40, #  치매검사여부             60739 non-null  object
    
    #41  평생담배제품사용경험         89822 non-null  object -> 흡연자 or 금연자 대상이므로 모두 사용 경험이 있음. --
    
    #42  일반담배평생흡연량          89786 non-null  float64
    #43  매일흡연자하루흡연량         89822 non-null  float64 -> 값 처리 필요?
    
    #44  가끔흡연자월간흡연일수        3590 non-null   float64 --
    #45  가끔흡연자일평균흡연량        3595 non-null   float64
    
    #46  과거흡연자흡연기간_년        52018 non-null  float64 -> churn 1일 때 row만 유의미한 응답 --
    
    #47  과거흡연자흡연기간_월        52013 non-null  float64 --
    #48  과거흡연자하루평균흡연량       52037 non-null  float64
    #49  금연유지기간             52054 non-null  float64 --
    #50  궐련형전자담배평생사용        89816 non-null  object
    #51  궐련형매일사용자하루사용량      5920 non-null   float64 --
    #52  궐련형가끔사용자월간일수       2019 non-null   float64 --
    #53  궐련형가끔사용자일평균사용량     2020 non-null   float64 --
    #54  액상형전자담배평생사용        89817 non-null  float64 --
    #55  액상형전자담배현재사용        10432 non-null  float64 --
    
    #56  최근1년금연시도여부         89822 non-null  object --
    
    #57  금연계획               41947 non-null  object    --
    #58  가정내흡연자존재           89821 non-null  object
    #59  가정간접흡연노출           2184 non-null   object
    #60, 직장간접흡연노출           89821 non-null  object
    
    61, #  교육수준               89788 non-null  float64
    62, #  졸업상태               88269 non-null  float64
    63, #  경제활동여부             89818 non-null  object
    64, #  직업분류               64814 non-null  object
    65, #  종사상지위              64814 non-null  object
    66, #  혼인상태               89805 non-null  object
    67, #  drb_binge_monthly  7351 non-null   float64      -> 폭음 경험...
    68, #  age_group          89822 non-null  object
    
    #69,  is_single          89822 non-null  object
    #70  fma_14z1_add       88476 non-null  float64
    #71,   fma_14z1_log       88476 non-null  float64
    
    72 # fma_14z1_group     89571 non-null  object
    #73  fma_dementia_case  89797 non-null  object 치매 가족 여부
]
print(len(columns_3))
# Out:
# 32

# %%
# 모델이 학습할 데이터프레임 생성
df_test3 = df_merge_kor.iloc[:, columns_3]
df_test3['수면시간'] = df_merge_kor['수면시간']

# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test3.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test3.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test3[col] = df_test3[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

# %%
# 모델

# 데이터 분리
X = df_test3.drop('이탈여부', axis=1)
y = df_test3['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    verbose=100
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 32) (71857,) (17965, 32) (17965,)
#
# 0:	learn: 0.6561504	total: 200ms	remaining: 1m 39s
# 100:	learn: 0.6940590	total: 14s	remaining: 55.2s
# 200:	learn: 0.6998761	total: 27.7s	remaining: 41.3s
# 300:	learn: 0.7040511	total: 42.5s	remaining: 28.1s
# 400:	learn: 0.7068762	total: 59.5s	remaining: 14.7s
# 499:	learn: 0.7087688	total: 1m 15s	remaining: 0us
# Accuracy: 0.6912329529640968
# age_group           16.064192
# 혼인상태                 8.954035
# 한 번 섭취 시 음주량         7.587469
# 교육수준                 5.649693
# 아침식사빈도               5.480725
# 화장실각성여부              4.483641
# 연간 음주 빈도             4.233881
# 성별                   4.132125
# 평생 음주 여부             3.329799
# 최근 1주일 유연성 운동 실천     3.039897
# 치매검사여부               2.771469
# 직업분류                 2.645748
# 수면시간                 2.556893
# 스트레스정도               2.541642
# 점심후양치여부              2.532734
# 구강건강자기평가             2.474777
# 절주 또는 금주계획 여부        2.148715
# 가구원수_전체              1.881540
# ...

# %%
# 중요도 내림차순 정렬
feature_importance = feature_importance.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance.T.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 모델 테스트 4

# %%
# 피쳐 선택
# 중요도 알아보기 위해 한 번 모두 넣고 학습
columns_4 = [
    #0   조사대상자번호            89822 non-null  object
    #1   만나이                89822 non-null  float64

    2,  #   성별                 89822 non-null  object
    3,  #   시도번호               89822 non-null  object

    #4   표본지점번호             89822 non-null  object
    #5   개인가중치              89822 non-null  float64

    6,  #   가구원수_전체            89822 non-null  float64

    7,  #   가구원수_만19세이상        89822 non-null  float64

    8,  #   기초생활수급자여부          89801 non-null  object
    
    #9   월간가구총소득구간          1095 non-null   float64
    
    10, #  가구식품안정성여부          89800 non-null  object
    11, #  이탈여부               89822 non-null  int64  ------------------------------------> churn
    12, #  아침식사빈도             89822 non-null  float64
    
    13, #  영양표시설인지여부          89315 non-null  float64
    14, #  영양표시영향여부           19738 non-null  float64
    
    15, #  체중조절방법_운동          44065 non-null  object
    16, #  체중조절방법_단식          44058 non-null  object          -> 이거 어떻ㄱ게 하고 싶은데. . .
    17, #  체중조절방법_무처방약물       44058 non-null  object
    
    18, #  구강건강자기평가           89822 non-null  object
    19, #  저작불편여부             89822 non-null  object
    20, #  점심후양치여부            89812 non-null  object
    
    #21  점심후양치불가이유          36451 non-null  object
    
    22, #  저녁양치여부             89817 non-null  object  -> 이것도 어떻게 하고 싶은데...
    
    #23  치과미수진이유            11794 non-null  object

    24, #  평생 음주 여부           89822 non-null  object
    25, #  연간 음주 빈도           89820 non-null  float64
    26, #  한 번 섭취 시 음주량       89819 non-null  float64
    27, #  절주 또는 금주계획 여부      66997 non-null  float64
    28, #  고강도 신체활동 일수        89822 non-null  float64
    29, #  중강도 신체활동 일수        89820 non-null  float64
    30, # 걷기 실천 일수           89818 non-null  float64
    31, #  최근 1주일 유연성 운동 실천   89821 non-null  float64
    
    32, #  스트레스정도             89802 non-null  float64
    
    #33  스트레스상담여부           19337 non-null  object
    
    #34  취침시간               89587 non-null  float64
    #35  기상시간               62246 non-null  float64
    
    36, #  화장실각성여부            89818 non-null  object
    
    37, #  악몽경험여부             89807 non-null  object
    
    38, #  기억력저하여부            74573 non-null  object
    
    39, #  상담여부               16733 non-null  object
    
    40, #  치매검사여부             60739 non-null  object
    
    #41  평생담배제품사용경험         89822 non-null  object -> 흡연자 or 금연자 대상이므로 모두 사용 경험이 있음. --
    
    #42  일반담배평생흡연량          89786 non-null  float64
    #43  매일흡연자하루흡연량         89822 non-null  float64 -> 값 처리 필요?
    
    #44  가끔흡연자월간흡연일수        3590 non-null   float64 --
    #45  가끔흡연자일평균흡연량        3595 non-null   float64
    
    #46  과거흡연자흡연기간_년        52018 non-null  float64 -> churn 1일 때 row만 유의미한 응답 --
    
    #47  과거흡연자흡연기간_월        52013 non-null  float64 --
    #48  과거흡연자하루평균흡연량       52037 non-null  float64
    #49  금연유지기간             52054 non-null  float64 --
    #50  궐련형전자담배평생사용        89816 non-null  object
    #51  궐련형매일사용자하루사용량      5920 non-null   float64 --
    #52  궐련형가끔사용자월간일수       2019 non-null   float64 --
    #53  궐련형가끔사용자일평균사용량     2020 non-null   float64 --
    #54  액상형전자담배평생사용        89817 non-null  float64 --
    #55  액상형전자담배현재사용        10432 non-null  float64 --
    
    #56  최근1년금연시도여부         89822 non-null  object --
    
    #57  금연계획               41947 non-null  object    --
    #58  가정내흡연자존재           89821 non-null  object
    #59  가정간접흡연노출           2184 non-null   object
    #60, 직장간접흡연노출           89821 non-null  object
    
    61, #  교육수준               89788 non-null  float64
    62, #  졸업상태               88269 non-null  float64
    63, #  경제활동여부             89818 non-null  object
    64, #  직업분류               64814 non-null  object
    65, #  종사상지위              64814 non-null  object
    66, #  혼인상태               89805 non-null  object
    67, #  drb_binge_monthly  7351 non-null   float64      -> 폭음 경험...
    68, #  age_group          89822 non-null  object
    
    69, #  is_single          89822 non-null  object
    #70  fma_14z1_add       88476 non-null  float64
    #71,   fma_14z1_log       88476 non-null  float64
    
    72, # fma_14z1_group     89571 non-null  object
    73 #  fma_dementia_case  89797 non-null  object 치매 가족 여부
]
print(len(columns_4))
# Out:
# 42

# %%
# 모델이 학습할 데이터프레임 생성
df_test4 = df_merge_kor.iloc[:, columns_4]
df_test4['수면시간'] = df_merge_kor['수면시간']

# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test4.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test4.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test4[col] = df_test4[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

# %%
# 모델

# 데이터 분리
X = df_test4.drop('이탈여부', axis=1)
y = df_test4['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    verbose=100
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 42) (71857,) (17965, 42) (17965,)
#
# 0:	learn: 0.6528939	total: 153ms	remaining: 1m 16s
# 100:	learn: 0.6965640	total: 22.3s	remaining: 1m 28s
# 200:	learn: 0.7023394	total: 56.4s	remaining: 1m 23s
# 300:	learn: 0.7072519	total: 2m 42s	remaining: 1m 47s
# 400:	learn: 0.7102857	total: 4m 1s	remaining: 59.6s
# 499:	learn: 0.7125959	total: 4m 40s	remaining: 0us
# Accuracy: 0.6960200389646535
# age_group           16.056727
# 혼인상태                 8.334055
# 한 번 섭취 시 음주량         7.434395
# 아침식사빈도               5.758790
# 교육수준                 4.981234
# 체중조절방법_운동            4.338337
# 화장실각성여부              3.966342
# 치매검사여부               3.930303
# 성별                   3.651655
# 연간 음주 빈도             3.422676
# 평생 음주 여부             3.134111
# 스트레스정도               2.358608
# 구강건강자기평가             2.112377
# 직업분류                 2.006760
# 절주 또는 금주계획 여부        1.943128
# 최근 1주일 유연성 운동 실천     1.929090
# 수면시간                 1.868248
# 체중조절방법_무처방약물         1.770508
# ...

# %%
# 중요도 내림차순 정렬
feature_importance4 = feature_importance.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance4.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 모델 테스트 5

# %%
# 상위 30개 피처 추출
top_features = selected_features = feature_importance4[feature_importance4 >= 1].index.tolist()

df_test5 = df_test4[top_features]
# 남은 칼럼명 리스트 추출
remaining_cols = df_test5.columns.tolist()

print(remaining_cols)
# Out:
# ['기초생활수급자여부', 'drb_binge_monthly', '졸업상태', '시도번호', 'fma_14z1_group', '가구원수_전체', '체중조절방법_단식', '저작불편여부', '점심후양치여부', '체중조절방법_무처방약물', '수면시간', '최근 1주일 유연성 운동 실천', '절주 또는 금주계획 여부', '직업분류', '구강건강자기평가', '스트레스정도', '평생 음주 여부', '연간 음주 빈도', '성별', '치매검사여부', '화장실각성여부', '체중조절방법_운동', '교육수준', '아침식사빈도', '한 번 섭취 시 음주량', '혼인상태', 'age_group']

# %%
# 모델이 학습할 데이터프레임 생성

# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test5.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test5.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test5[col] = df_test5[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

# %%
# 모델

# 데이터 분리
X = df_test5
y = df_test4['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    verbose=100
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance5 = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance5.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 27) (71857,) (17965, 27) (17965,)
#
# 0:	learn: 0.6544665	total: 214ms	remaining: 1m 46s
# 100:	learn: 0.6971903	total: 19s	remaining: 1m 15s
# 200:	learn: 0.7022420	total: 39s	remaining: 58s
# 300:	learn: 0.7066257	total: 59.9s	remaining: 39.6s
# 400:	learn: 0.7096455	total: 1m 16s	remaining: 19s
# 499:	learn: 0.7115799	total: 1m 30s	remaining: 0us
# Accuracy: 0.6951294183133871
# age_group           17.388278
# 혼인상태                 9.032789
# 한 번 섭취 시 음주량         7.820846
# 아침식사빈도               6.193379
# 체중조절방법_운동            5.701570
# 교육수준                 4.830178
# 성별                   4.394141
# 화장실각성여부              4.075643
# 치매검사여부               3.802301
# 연간 음주 빈도             3.504165
# 평생 음주 여부             3.292662
# 직업분류                 3.126663
# 스트레스정도               2.518671
# 구강건강자기평가             2.452374
# 수면시간                 2.314286
# 절주 또는 금주계획 여부        2.240476
# 최근 1주일 유연성 운동 실천     2.228214
# 저작불편여부               2.040576
# ...

# %%
# 중요도 내림차순 정렬
feature_importance5 = feature_importance5.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance5.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 체중조절방법 파생 변수

# %%
# 체중조절방법 관련 칼럼 통합

cols = ["체중조절방법_운동", "체중조절방법_단식", "체중조절방법_무처방약물"]

# 세 컬럼 모두 NaN인 행의 개수
all_nan_count = df_merge_kor[cols].isna().all(axis=1).sum()

print(f"세 개의 칼럼이 모두 NaN인 행 개수: {all_nan_count}")

# NaN을 '비응답'으로 대체하고, 세 칼럼을 조합한 문자열 생성
df_merge_kor["체중조절방법"] = (
    df_merge_kor[cols]
    .fillna("비응답")          # NaN → '비응답'
    .astype(str)               # 숫자를 문자열로 변환
    .agg("-".join, axis=1)     # 3개 값을 '-'로 연결
)

# 결과 확인
print(df_merge_kor["체중조절방법"].head())
# Out:
# 세 개의 칼럼이 모두 NaN인 행 개수: 45757
# 0    1.0-2.0-2.0
# 1    비응답-비응답-비응답
# 2    2.0-2.0-2.0
# 3    1.0-2.0-2.0
# 4    비응답-비응답-비응답
# Name: 체중조절방법, dtype: object

# %% [markdown]
# ##### 모델 테스트 6

# %%
# NaN 비율 확인 (30퍼 넘는 것 존재 x)
# df_test5.isna().mean().sort_values(ascending=False)
# Out:
# 절주 또는 금주계획 여부       0.254114
# 졸업상태                0.017290
# 수면시간                0.004531
# 교육수준                0.000379
# 스트레스정도              0.000223
# 한 번 섭취 시 음주량        0.000033
# 연간 음주 빈도            0.000022
# 최근 1주일 유연성 운동 실천    0.000011
# 시도번호                0.000000
# drb_binge_monthly   0.000000
# 기초생활수급자여부           0.000000
# 체중조절방법_무처방약물        0.000000
# 점심후양치여부             0.000000
# 저작불편여부              0.000000
# 체중조절방법_단식           0.000000
# fma_14z1_group      0.000000
# 가구원수_전체             0.000000
# 구강건강자기평가            0.000000
# 직업분류                0.000000
# 성별                  0.000000
# 평생 음주 여부            0.000000
# 화장실각성여부             0.000000
# 치매검사여부              0.000000
# 체중조절방법_운동           0.000000
# 아침식사빈도              0.000000
# 혼인상태                0.000000
# age_group           0.000000
# dtype: float64

# %%
# 모델이 학습할 데이터프레임 생성
# 'drb_binge_monthly', '평생 음주 여부' 제거, '체중조절방법' 추가
df_test6 = df_test5.drop(['drb_binge_monthly', '평생 음주 여부']+cols, axis=1)
df_test6['체중조절방법'] = df_merge_kor['체중조절방법']


# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test6.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test6.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test6[col] = df_test6[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

# %%
# 모델

# 데이터 분리
X = df_test6
y = df_test4['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    verbose=100
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance6 = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance6.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 23) (71857,) (17965, 23) (17965,)
#
# 0:	learn: 0.6540490	total: 165ms	remaining: 1m 22s
# 100:	learn: 0.6946574	total: 17.4s	remaining: 1m 8s
# 200:	learn: 0.7005024	total: 34.7s	remaining: 51.6s
# 300:	learn: 0.7039537	total: 48s	remaining: 31.7s
# 400:	learn: 0.7067509	total: 1m 1s	remaining: 15.2s
# 499:	learn: 0.7086714	total: 1m 14s	remaining: 0us
# Accuracy: 0.69167826328973
# age_group          17.571192
# 혼인상태                9.189641
# 체중조절방법              8.402270
# 한 번 섭취 시 음주량        7.237312
# 아침식사빈도              5.800147
# 교육수준                5.721294
# 성별                  5.162023
# 화장실각성여부             4.713316
# 치매검사여부              4.058222
# 연간 음주 빈도            3.601796
# 직업분류                3.198486
# 구강건강자기평가            2.797795
# 최근 1주일 유연성 운동 실천    2.699481
# 스트레스정도              2.666504
# 수면시간                2.576278
# 절주 또는 금주계획 여부       2.385558
# 점심후양치여부             2.161127
# 저작불편여부              1.968077
# 가구원수_전체             1.836725
# ...

# %%
# 중요도 내림차순 정렬
feature_importance6 = feature_importance6.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance6.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 활동수준_가중치 파생 변수 생성

# %%
# 고강도, 중강도, 걷기 활동으로 파생 변수 생성

df_merge_kor["활동점수_가중치"] = (
    3 * df_merge_kor["고강도 신체활동 일수"].fillna(0) +
    2 * df_merge_kor["중강도 신체활동 일수"].fillna(0) +
    1 * df_merge_kor["걷기 실천 일수"].fillna(0)
)

def activity_level(x):
    if x >= 10:
        return "활동적"
    elif x >= 5:
        return "보통"
    elif x >= 1:
        return "저활동"
    else:
        return "비활동"

df_merge_kor["활동수준"] = df_merge_kor["활동점수_가중치"].apply(activity_level)
print(df_merge_kor['활동점수_가중치'].value_counts(), df_merge_kor['활동수준'].value_counts())
# Out:
# 활동점수_가중치
# 7.000000     17753
# 0.000000      9498
# 5.000000      6284
# 3.000000      4861
# 2.000000      3540
# 6.000000      3475
# 21.000000     3090
# 4.000000      2999
# 13.000000     2819
# 9.000000      2539
# 15.000000     2512
# 17.000000     2475
# 10.000000     2425
# 12.000000     2276
# 11.000000     2221
# 14.000000     1947
# 1.000000      1719
# 16.000000     1641
# 22.000000     1512
# 8.000000      1430
# 19.000000     1350
# 18.000000     1309
# 20.000000     1271
# 42.000000     1216
# 30.000000      992
# 32.000000      854
# 28.000000      852
# 24.000000      716
# 25.000000      689
# 27.000000      680
# 23.000000      473
# 26.000000      470
# 36.000000      424
# 35.000000      296
# 37.000000      269
# 31.000000      189
# 33.000000      171
# 29.000000      166
# 34.000000      145
# 38.000000      122
# 39.000000       75
# 40.000000       66
# 41.000000       11
# Name: count, dtype: int64 활동수준
# 활동적    35724
# 보통     31481
# 저활동    13119
# ...

# %% [markdown]
# ##### 모델 테스트 7

# %%
# 모델이 학습할 데이터프레임 생성

df_test7 = df_test6.copy()
df_test7['평생 음주 여부'] = df_merge_kor['평생 음주 여부']
df_test7['활동점수_가중치'] = df_merge_kor['활동점수_가중치']


# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test7.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test7.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test7[col] = df_test7[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

# %%
# 모델

# 데이터 분리
X = df_test7
y = df_test4['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    verbose=100
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance7 = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance7.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 25) (71857,) (17965, 25) (17965,)
#
# 0:	learn: 0.6524347	total: 180ms	remaining: 1m 29s
# 100:	learn: 0.6969119	total: 17s	remaining: 1m 7s
# 200:	learn: 0.7023950	total: 39.4s	remaining: 58.6s
# 300:	learn: 0.7059855	total: 1m 6s	remaining: 43.8s
# 400:	learn: 0.7091167	total: 1m 32s	remaining: 22.9s
# 499:	learn: 0.7119139	total: 1m 59s	remaining: 0us
# Accuracy: 0.6947954355691622
# age_group          18.026195
# 혼인상태                8.677044
# 체중조절방법              7.676291
# 한 번 섭취 시 음주량        7.654022
# 아침식사빈도              5.631241
# 교육수준                5.385640
# 성별                  4.734278
# 화장실각성여부             4.255997
# 연간 음주 빈도            3.731071
# 평생 음주 여부            3.119422
# 치매검사여부              3.116192
# 직업분류                3.070036
# 구강건강자기평가            2.607300
# 스트레스정도              2.362398
# 활동점수_가중치            2.231609
# 최근 1주일 유연성 운동 실천    2.155788
# 절주 또는 금주계획 여부       2.085124
# 점심후양치여부             2.015109
# 수면시간                1.970376
# ...

# %%
# 중요도 내림차순 정렬
feature_importance7 = feature_importance7.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance7.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 모델 테스트 7-1

# %%
# 모델

# 데이터 분리
X = df_test7
y = df_test4['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 1. 모델 정의
model = CatBoostClassifier(
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance7 = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance7.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 25) (71857,) (17965, 25) (17965,)
#
# Learning rate set to 0.063921
# 0:	learn: 0.6524347	total: 201ms	remaining: 3m 21s
# 1:	learn: 0.6660451	total: 389ms	remaining: 3m 14s
# 2:	learn: 0.6675898	total: 530ms	remaining: 2m 56s
# 3:	learn: 0.6715838	total: 658ms	remaining: 2m 43s
# 4:	learn: 0.6740888	total: 808ms	remaining: 2m 40s
# 5:	learn: 0.6731703	total: 948ms	remaining: 2m 37s
# 6:	learn: 0.6737966	total: 1.09s	remaining: 2m 34s
# 7:	learn: 0.6741445	total: 1.23s	remaining: 2m 32s
# 8:	learn: 0.6747011	total: 1.35s	remaining: 2m 29s
# 9:	learn: 0.6759119	total: 1.48s	remaining: 2m 26s
# 10:	learn: 0.6759815	total: 1.6s	remaining: 2m 23s
# 11:	learn: 0.6776932	total: 1.73s	remaining: 2m 22s
# 12:	learn: 0.6783612	total: 1.85s	remaining: 2m 20s
# 13:	learn: 0.6788483	total: 2s	remaining: 2m 20s
# 14:	learn: 0.6795998	total: 2.13s	remaining: 2m 19s
# 15:	learn: 0.6804904	total: 2.27s	remaining: 2m 19s
# 16:	learn: 0.6805878	total: 2.42s	remaining: 2m 19s
# ...

# %% [markdown]
# ### churn과의 관련있는 column으로 CatBoost 진행

# %% [markdown]
# ##### SHAP

# %%
# !pip install shap
# Out:
# ...
#    ---------------------------------------- 0.0/545.3 kB ? eta -:--:--
#    ---------------------------------------- 545.3/545.3 kB 3.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 5.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.1 MB 4.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/38.1 MB 3.7 MB/s eta 0:00:10
#    -- ------------------------------------- 2.4/38.1 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 2.9/38.1 MB 3.5 MB/s eta 0:00:11
#    --- ------------------------------------ 3.7/38.1 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.0/38.1 MB 4.0 MB/s eta 0:00:09
# ...

# %%
# 흡연 관련 칼럼 제거
columns_shap = [
    #0   조사대상자번호            89822 non-null  object
    #1   만나이                89822 non-null  float64

    2,  #   성별                 89822 non-null  object
    3,  #   시도번호               89822 non-null  object

    #4   표본지점번호             89822 non-null  object
    #5   개인가중치              89822 non-null  float64

    6,  #   가구원수_전체            89822 non-null  float64

    7,  #   가구원수_만19세이상        89822 non-null  float64

    8,  #   기초생활수급자여부          89801 non-null  object
    
    #9   월간가구총소득구간          1095 non-null   float64
    
    10, #  가구식품안정성여부          89800 non-null  object
    11, #  이탈여부               89822 non-null  int64  ------------------------------------> churn
    12, #  아침식사빈도             89822 non-null  float64
    
    13, #  영양표시설인지여부          89315 non-null  float64
    14, #  영양표시영향여부           19738 non-null  float64
    
    15, #  체중조절방법_운동          44065 non-null  object
    16, #  체중조절방법_단식          44058 non-null  object          -> 이거 어떻ㄱ게 하고 싶은데. . .
    17, #  체중조절방법_무처방약물       44058 non-null  object
    
    18, #  구강건강자기평가           89822 non-null  object
    19, #  저작불편여부             89822 non-null  object
    20, #  점심후양치여부            89812 non-null  object
    
    #21  점심후양치불가이유          36451 non-null  object
    
    22, #  저녁양치여부             89817 non-null  object  -> 이것도 어떻게 하고 싶은데...
    
    #23  치과미수진이유            11794 non-null  object

    24, #  평생 음주 여부           89822 non-null  object
    25, #  연간 음주 빈도           89820 non-null  float64
    26, #  한 번 섭취 시 음주량       89819 non-null  float64
    27, #  절주 또는 금주계획 여부      66997 non-null  float64
    28, #  고강도 신체활동 일수        89822 non-null  float64
    29, #  중강도 신체활동 일수        89820 non-null  float64
    30, # 걷기 실천 일수           89818 non-null  float64
    31, #  최근 1주일 유연성 운동 실천   89821 non-null  float64
    
    32, #  스트레스정도             89802 non-null  float64
    
    #33  스트레스상담여부           19337 non-null  object
    
    #34  취침시간               89587 non-null  float64
    #35  기상시간               62246 non-null  float64
    
    36, #  화장실각성여부            89818 non-null  object
    
    37, #  악몽경험여부             89807 non-null  object
    
    38, #  기억력저하여부            74573 non-null  object
    
    39, #  상담여부               16733 non-null  object
    
    40, #  치매검사여부             60739 non-null  object
    
    #41  평생담배제품사용경험         89822 non-null  object -> 흡연자 or 금연자 대상이므로 모두 사용 경험이 있음. --
    
    #42  일반담배평생흡연량          89786 non-null  float64
    #43  매일흡연자하루흡연량         89822 non-null  float64 -> 값 처리 필요?
    
    #44  가끔흡연자월간흡연일수        3590 non-null   float64 --
    #45  가끔흡연자일평균흡연량        3595 non-null   float64
    
    #46  과거흡연자흡연기간_년        52018 non-null  float64 -> churn 1일 때 row만 유의미한 응답 --
    
    #47  과거흡연자흡연기간_월        52013 non-null  float64 --
    #48  과거흡연자하루평균흡연량       52037 non-null  float64
    #49  금연유지기간             52054 non-null  float64 --
    #50  궐련형전자담배평생사용        89816 non-null  object
    #51  궐련형매일사용자하루사용량      5920 non-null   float64 --
    #52  궐련형가끔사용자월간일수       2019 non-null   float64 --
    #53  궐련형가끔사용자일평균사용량     2020 non-null   float64 --
    #54  액상형전자담배평생사용        89817 non-null  float64 --
    #55  액상형전자담배현재사용        10432 non-null  float64 --
    
    #56  최근1년금연시도여부         89822 non-null  object --
    
    #57  금연계획               41947 non-null  object    --
    58, #  가정내흡연자존재           89821 non-null  object
    #59  가정간접흡연노출           2184 non-null   object
    60, # 직장간접흡연노출           89821 non-null  object
    
    61, #  교육수준               89788 non-null  float64
    62, #  졸업상태               88269 non-null  float64
    63, #  경제활동여부             89818 non-null  object
    64, #  직업분류               64814 non-null  object
    65, #  종사상지위              64814 non-null  object
    66, #  혼인상태               89805 non-null  object
    67, #  drb_binge_monthly  7351 non-null   float64      -> 폭음 경험...
    68, #  age_group          89822 non-null  object
    
    69, #  is_single          89822 non-null  object
    #70  fma_14z1_add       88476 non-null  float64
    #71,   fma_14z1_log       88476 non-null  float64
    
    72, # fma_14z1_group     89571 non-null  object
    73 #  fma_dementia_case  89797 non-null  object 치매 가족 여부
]
print(len(columns_shap))
# Out:
# 44

# %%
# SHAP 분석할 데이터프레임 생성
df_shap = df_merge_kor.iloc[:, columns_shap]
df_shap['수면시간'] = df_merge_kor['수면시간']
df_shap['체중조절방법'] = df_merge_kor['체중조절방법']
df_shap['활동점수_가중치'] = df_merge_kor['활동점수_가중치']

# %%
from catboost import CatBoostClassifier, Pool
import shap

# -------------------------
# Feature와 target 설정
# -------------------------
target_col = "이탈여부"  # 1: 금연자, 0: 흡연자
feature_cols = [col for col in df_shap.columns if col != target_col]

# 범주형 피처의 인덱스 번호 리스트 추출
categorical_features = [i for i, dtype in enumerate(df_shap.dtypes)
                if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
categorical_features_names = [df_shap.columns[i] for i in categorical_features]
categorical_features_names = [col for col in categorical_features_names if col != target_col]

# NaN을 missing으로 저장
for col in categorical_features_names:
    df_shap[col] = df_shap[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)

X = df_shap[feature_cols]
y = df_shap[target_col]

# -------------------------
# CatBoost 모델 학습
# -------------------------
model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.05,
    depth=6,
    eval_metric='Accuracy',
    random_seed=2,
    verbose=100
)

train_pool = Pool(X, y, cat_features=categorical_features_names)
model.fit(train_pool)

# -------------------------
# SHAP 값 계산
# -------------------------
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

# -------------------------
# Feature 중요도 분석
# -------------------------
shap_abs_mean = pd.DataFrame({
    "feature": X.columns,
    "mean_abs_shap": np.abs(shap_values).mean(axis=0)
}).sort_values("mean_abs_shap", ascending=False)

# 중요도 낮은 feature 제거 기준: mean |SHAP| < 0.01
low_importance_features = shap_abs_mean[shap_abs_mean["mean_abs_shap"] < 0.01]["feature"].tolist()
print("SHAP 기반 중요도 낮은 feature:", low_importance_features)

# signal 있는 feature만 선별
signal_features = shap_abs_mean[shap_abs_mean["mean_abs_shap"] >= 0.01]["feature"].tolist()
print("신호 있는 feature 개수:", len(signal_features))
print("상위 20개 signal feature:")
print(signal_features[:20])

# -------------------------
# signal feature로 재학습
# -------------------------
X_signal = df_merge_kor[signal_features]
model_signal = CatBoostClassifier(
    iterations=500,
    learning_rate=0.05,
    depth=6,
    eval_metric='Accuracy',
    random_seed=42,
    verbose=100
)
model_signal.fit(Pool(X_signal, y, cat_features=[col for col in signal_features if df_merge_kor[col].dtype=='object']))
# Out:
# 0:	learn: 0.6611521	total: 318ms	remaining: 2m 38s
# 100:	learn: 0.6974349	total: 40.9s	remaining: 2m 41s
# 200:	learn: 0.7024448	total: 1m 10s	remaining: 1m 44s
# 300:	learn: 0.7054953	total: 1m 40s	remaining: 1m 6s
# 400:	learn: 0.7087017	total: 2m 10s	remaining: 32.3s
# 499:	learn: 0.7110173	total: 2m 40s	remaining: 0us
# SHAP 기반 중요도 낮은 feature: ['가구식품안정성여부', '체중조절방법_무처방약물', '고강도 신체활동 일수', 'drb_binge_monthly', '걷기 실천 일수', 'fma_dementia_case', '경제활동여부', 'is_single', '종사상지위', '중강도 신체활동 일수', '가구원수_만19세이상', '영양표시설인지여부', '악몽경험여부']
# 신호 있는 feature 개수: 33
# 상위 20개 signal feature:
# ['age_group', '한 번 섭취 시 음주량', '혼인상태', '아침식사빈도', '화장실각성여부', '체중조절방법_운동', '교육수준', '연간 음주 빈도', '스트레스정도', '최근 1주일 유연성 운동 실천', '점심후양치여부', '평생 음주 여부', '치매검사여부', '구강건강자기평가', '절주 또는 금주계획 여부', '직업분류', '성별', '가정내흡연자존재', '저작불편여부', '활동점수_가중치']
# 0:	learn: 0.6694240	total: 271ms	remaining: 2m 14s
# 100:	learn: 0.6978803	total: 31s	remaining: 2m 2s
# 200:	learn: 0.7033689	total: 58.8s	remaining: 1m 27s
# ...

# %%
feature_importance_shap = pd.Series(model_signal.feature_importances_, index=X_signal.columns)
# print(feature_importance_shap.sort_values(ascending=False), '\n')

# 중요도 내림차순 정렬
feature_importance_shap = feature_importance_shap.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance_shap.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### shap 분석으로 signal 높은 칼럼 정리 후 재학습 (파생 변수 관련 기존 변수 제거 등)

# %%
signal_features.remove('체중조절방법_운동')
signal_features.remove('체중조절방법_단식')

X_signal = df_merge_kor[signal_features]
model_signal = CatBoostClassifier(
    iterations=500,
    learning_rate=0.05,
    depth=6,
    eval_metric='Accuracy',
    random_seed=42,
    verbose=100
)
model_signal.fit(Pool(X_signal, y, cat_features=[col for col in signal_features if df_merge_kor[col].dtype=='object']))
# Out:
# 0:	learn: 0.6618089	total: 287ms	remaining: 2m 23s
# 100:	learn: 0.6977133	total: 27.3s	remaining: 1m 47s
# 200:	learn: 0.7028679	total: 53.9s	remaining: 1m 20s
# 300:	learn: 0.7062412	total: 1m 21s	remaining: 54s
# 400:	learn: 0.7085569	total: 1m 49s	remaining: 26.9s
# 499:	learn: 0.7106277	total: 2m 16s	remaining: 0us

# %%
feature_importance_shap2 = pd.Series(model_signal.feature_importances_, index=X_signal.columns)
# print(feature_importance_shap2.sort_values(ascending=False), '\n')

# 중요도 내림차순 정렬
feature_importance_shap2 = feature_importance_shap2.sort_values(ascending=True)

# 막대그래프 시각화
plt.figure(figsize=(10, 6))
feature_importance_shap2.plot(kind='barh')

plt.title('Feature Importance (CatBoost)')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# test7 모델의 피쳐 중요도와 비교. 6개의 피쳐가 새로 추가되었음

set(feature_importance_shap2.index) - set(feature_importance7.index)
# print(feature_importance_shap2.shape, feature_importance7.shape)
# Out:
# {'가정내흡연자존재', '기억력저하여부', '상담여부', '영양표시영향여부', '저녁양치여부', '직장간접흡연노출'}

# %% [markdown]
# ##### 최종 피쳐로 모델 학습

# %%
# CatBoost 모델

df_test_final = df_merge_kor[signal_features]

# 범주형 피처의 인덱스 번호 리스트 추출
cat_features = [i for i, dtype in enumerate(df_test_final.dtypes) if dtype == 'object']

# 범주형 컬럼 이름 리스트 추출
cat_features_names = [df_test_final.columns[i] for i in cat_features]

# 모든 범주형 컬럼 float → 문자열로 변환
for col in cat_features_names:
    df_test_final[col] = df_test_final[col].replace([np.nan, np.inf, -np.inf], 'missing').astype(str)


# 데이터 분리
X = df_test_final
y = df_merge_kor['이탈여부']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
# 모델 정의
model_final = CatBoostClassifier(
    iterations=500,     # 트리 개수
    learning_rate=0.05, # 학습률
    depth=6,            # 트리 깊이
    cat_features=cat_features_names,  # 범주형 변수 인덱스
    eval_metric='Accuracy',
    random_state=2,
    verbose=100
)
# 학습
model_final.fit(Pool(X_train, y_train, cat_features=cat_features))


# 예측 및 평가
y_pred = model_final.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))


# 변수중요도
feature_importance_final = pd.Series(model_final.feature_importances_, index=X.columns)
print(feature_importance_final.sort_values(ascending=False), '\n')


# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_test = y_test.astype(int)
y_prob = model_final.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 31) (71857,) (17965, 31) (17965,)
#
# 0:	learn: 0.6513910	total: 333ms	remaining: 2m 46s
# 100:	learn: 0.6982757	total: 26.1s	remaining: 1m 43s
# 200:	learn: 0.7034944	total: 52s	remaining: 1m 17s
# 300:	learn: 0.7078503	total: 1m 17s	remaining: 51.5s
# 400:	learn: 0.7116495	total: 1m 44s	remaining: 25.7s
# 499:	learn: 0.7138623	total: 2m 10s	remaining: 0us
# Accuracy: 0.6975786251043696
# age_group          14.594883
# 혼인상태                8.695665
# 한 번 섭취 시 음주량        7.883175
# 체중조절방법              7.111637
# 아침식사빈도              5.947381
# 교육수준                4.814102
# 성별                  4.618665
# 화장실각성여부             4.040032
# 치매검사여부              3.849649
# 연간 음주 빈도            3.278584
# 평생 음주 여부            3.019768
# 직업분류                2.557402
# 구강건강자기평가            2.413969
# 가정내흡연자존재            2.382300
# 스트레스정도              2.295508
# 최근 1주일 유연성 운동 실천    2.235005
# 활동점수_가중치            1.984416
# 절주 또는 금주계획 여부       1.952960
# 수면시간                1.714164
# ...

# %% [markdown]
# ##### 검증, 하이퍼 파라미터 튜닝

# %%
# 교차 검증 1
from sklearn.model_selection import cross_val_score, StratifiedKFold

# 교차검증 설정 (5-Fold 예시)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=2)

# CatBoost 모델 정의 (현재 베이스라인)
model_final = CatBoostClassifier(
    iterations=500,
    learning_rate=0.05,
    depth=6,
    cat_features=cat_features_names,
    eval_metric='Accuracy',
    random_state=2,
    verbose=0
)

# 교차검증 수행 1
cv_scores = cross_val_score(model_final, X_train, y_train, cv=cv, scoring='accuracy')

print("CV 개별 점수:", cv_scores)
print("CV 평균:", np.mean(cv_scores))
print("CV 표준편차:", np.std(cv_scores))
# Out:
# CV 개별 점수: [0.69969385 0.70386863 0.70517013 0.69013987 0.69633289]
# CV 평균: 0.6990410749080426
# CV 표준편차: 0.005438062039044983

# %%
# 교차 검증 2
from sklearn.model_selection import cross_validate

scores = cross_validate(model_final, X_train, y_train,
                        cv=cv, scoring=('accuracy', 'f1'),
                        return_train_score=True
                        )
scores
# Out:
# {'fit_time': array([246.06114578, 209.30057311, 255.82954359, 296.393255  ,
#         274.72152758]),
#  'score_time': array([0.43375134, 0.47998476, 0.5845027 , 0.53057837, 0.46740746]),
#  'test_accuracy': array([0.69969385, 0.70386863, 0.70517013, 0.69013987, 0.69633289]),
#  'train_accuracy': array([0.71195964, 0.71025485, 0.71041645, 0.71464357, 0.71151237]),
#  'test_f1': array([nan, nan, nan, nan, nan]),
#  'train_f1': array([nan, nan, nan, nan, nan])}

# %%
# 평가 지표 precision, recall, f1 점수
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

def evaluate_binary_classification(y_true, y_pred):
    print('혼동 행렬\n', confusion_matrix(y_true, y_pred))
    print('정확도:', accuracy_score(y_true, y_pred))
    print('정밀도:', precision_score(y_true, y_pred))
    print('재현율:', recall_score(y_true, y_pred))
    print('f1-score:', f1_score(y_true, y_pred))
    
y_pred = y_pred.astype(int)
evaluate_binary_classification(y_test, y_pred)
# Out:
# 혼동 행렬
#  [[5234 2888]
#  [2545 7298]]
# 정확도: 0.6975786251043696
# 정밀도: 0.7164735912036128
# 재현율: 0.7414406176978563
# f1-score: 0.7287433221828349

# %%
# 하이퍼 파라미터 튜닝 - 옵튜나 이용
import optuna
from sklearn.metrics import make_scorer

# 목적 함수 정의
def objective(trial):
    # 탐색할 하이퍼파라미터 공간 설정
    params = {
        'iterations': trial.suggest_int('iterations', 300, 800),
        'depth': trial.suggest_int('depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 10, log=True),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1),
        'verbose': 100,
        'random_seed': 2,
    }

    # 모델 정의
    model_op = CatBoostClassifier(**params, cat_features=cat_features_names, eval_metric='F1')

    # 교차검증 (StratifiedKFold 권장)
    cv_op = StratifiedKFold(n_splits=3, shuffle=True, random_state=2)
    scores_op = cross_val_score(model_op, X_train, y_train.astype(int), cv=cv_op, scoring=('accuracy', 'f1'))

    return scores_op.mean()  # Optuna는 maximize/minimize 기준으로 비교함

# 스터디 생성 및 최적화 실행
study = optuna.create_study(direction='maximize')  # F1 점수 최대화
study.optimize(objective, n_trials=30, show_progress_bar=True)

# 결과 확인
print("Best F1:", study.best_value)
print("Best Params:", study.best_params)

# %% [markdown]
# ### 고정된 포맷 저장

# %%
# 결측치 처리

# %%
# 파생 변수 생성

# %%
# 인코딩

# %%
# 최종 피처 선택 (예시)
fnl_col = ['age', 'sex', 'CTPRVN_CODE', 'SPOT_NO', 'mbhld_co', 'reside_adult_co',
       'fma_04z1', 'fma_24z2', 'nue_01z1', 'churn', 'nua_01z2', 'nuc_02z1',
       'nuc_03z1', 'obb_02a1', 'obb_02b1', 'obb_02d1', 'ora_01z1', 'orb_01z1',
       'ord_01d2', 'ord_05z1', 'ord_01f3', 'ore_03z2', 'dra_01z1', 'drb_01z3',
       'drb_03z1', 'drg_01z3', 'pha_04z1', 'pha_07z1', 'phb_01z1', 'pha_11z1',
       'mta_01z1', 'mta_02z1', 'edit_mtc_03z1', 'mtc_08z1', 'mtc_12c1',
       'mtc_12h1', 'mtj_05z2', 'mtj_10z1', 'mtj_11z1', 'smf_01z1',
       'smb_01z1', 'smb_02z1', 'smb_03z1', 'smb_04z1', 'smb_05z1',
       'smb_06z1', 'sma_36z1', 'smb_12z1',
       'sma_08z1', 'sma_11z2',
       'smc_08z2', 'smc_09z2', 'smc_10z2', 'sob_01z1', 'sob_02z1', 'soa_01z1',
       'soa_06z2', 'soa_07z1', 'sod_02z3', 'drb_binge_monthly', 'age_group',
       'is_single', 'fma_14z1_add', 'fma_14z1_log', 'fma_14z1_group',
       'fma_dementia_case']

# ['sma_03z2', 'sma_37z1', 'sma_12z2'] -> 타겟변수 만든 변수
# ['smd_02z3','smd_01z3', 'smb_09z1', 'smb_11z1', 'smb_13z1', 'sma_01z1', ...] 제외 -> 예측하고자 하는 타겟의 정보를 가지고있는 변수
df = df[fnl_col]

# %%
# 모델
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, average_precision_score, roc_curve, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 분리
X = df.drop('churn', axis=1)
y = df['churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, '\n')

# 모델 학습
model = DecisionTreeClassifier(random_state=2)
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# 변수중요도
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
print(feature_importance.sort_values(ascending=False), '\n')

# 혼동행렬
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC-AUC
y_prob = model.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, y_prob)
fpr, tpr, _ = roc_curve(y_test, y_prob)

# PR-AUC
pr_auc = average_precision_score(y_test, y_prob)
prec, recall, _ = precision_recall_curve(y_test, y_prob)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.3f}")
axes[0].plot([0,1],[0,1],'--')
axes[0].set_xlabel("FPR")
axes[0].set_ylabel("TPR")
axes[0].set_title("ROC Curve")
axes[0].legend()

axes[1].plot(recall, prec, label=f"PR-AUC = {pr_auc:.3f}")
axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curve")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# (71857, 65) (71857,) (17965, 65) (17965,)
#
# Accuracy: 0.9702198719732814
# smb_06z1            0.873343
# sma_36z1            0.053993
# sma_11z2            0.006367
# SPOT_NO             0.004656
# age                 0.004530
# smb_04z1            0.003638
# soa_06z2            0.003103
# CTPRVN_CODE         0.002968
# smb_12z1            0.002792
# pha_07z1            0.001884
# drb_03z1            0.001804
# edit_mtc_03z1       0.001711
# mtc_12c1            0.001672
# drb_01z3            0.001656
# pha_11z1            0.001606
# phb_01z1            0.001560
# ord_05z1            0.001559
# fma_14z1_add        0.001555
# smb_03z1            0.001548
# reside_adult_co     0.001503
# mbhld_co            0.001436
# fma_14z1_log        0.001434
# sob_01z1            0.001369
# orb_01z1            0.001339
# pha_04z1            0.001248
# drg_01z3            0.001232
# ora_01z1            0.001159
# smb_05z1            0.001091
# nua_01z2            0.001074
# ...
